# %% [markdown]
# ## Get The text from the PDF

# %%
# %pip install pdfplumber pytesseract pdf2image
# Out:
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.5-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 847.1 kB/s eta 0:00:00
# Collecting pytesseract
#   Downloading pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Collecting pdf2image
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting pdfminer.six==20231228 (from pdfplumber)
#   Downloading pdfminer.six-20231228-py3-none-any.whl.metadata (4.2 kB)
# Collecting Pillow>=9.1 (from pdfplumber)
#   Downloading pillow-11.1.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.1 kB)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Downloading pypdfium2-4.30.1-py3-none-macosx_11_0_arm64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.5 MB/s eta 0:00:00
# Collecting charset-normalizer>=2.0.0 (from pdfminer.six==20231228->pdfplumber)
#   Downloading charset_normalizer-3.4.1-cp312-cp312-macosx_10_13_universal2.whl.metadata (35 kB)
# Collecting cryptography>=36.0.0 (from pdfminer.six==20231228->pdfplumber)
#   Downloading cryptography-44.0.1-cp39-abi3-macosx_10_9_universal2.whl.metadata (5.7 kB)
# Requirement already satisfied: packaging>=21.3 in /Users/jayanth/Library/Python/3.12/lib/python/site-packages (from pytesseract) (24.0)
# Collecting cffi>=1.12 (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber)
#   Downloading cffi-1.17.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Collecting pycparser (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber)
#   Downloading pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Downloading pdfplumber-0.11.5-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 3.7 MB/s eta 0:00:00
# Downloading pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 6.4 MB/s eta 0:00:00a 0:00:01
# Downloading pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Downloading pillow-11.1.0-cp312-cp312-macosx_11_0_arm64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 6.3 MB/s eta 0:00:00a 0:00:01
# Downloading pypdfium2-4.30.1-py3-none-macosx_11_0_arm64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 5.8 MB/s eta 0:00:0000:0100:01
# Downloading charset_normalizer-3.4.1-cp312-cp312-macosx_10_13_universal2.whl (196 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.1/196.1 kB 6.6 MB/s eta 0:00:00
# Downloading cryptography-44.0.1-cp39-abi3-macosx_10_9_universal2.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 3.4 MB/s eta 0:00:0000:0100:01
# Downloading cffi-1.17.1-cp312-cp312-macosx_11_0_arm64.whl (178 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.8/178.8 kB 2.2 MB/s eta 0:00:00a 0:00:01
# Downloading pycparser-2.22-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.6/117.6 kB 2.1 MB/s eta 0:00:00 0:00:01
# Installing collected packages: pypdfium2, pycparser, Pillow, charset-normalizer, pytesseract, pdf2image, cffi, cryptography, pdfminer.six, pdfplumber
# Successfully installed Pillow-11.1.0 cffi-1.17.1 charset-normalizer-3.4.1 cryptography-44.0.1 pdf2image-1.17.0 pdfminer.six-20231228 pdfplumber-0.11.5 pycparser-2.22 pypdfium2-4.30.1 pytesseract-0.3.13
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pdfplumber
import pytesseract
from pdf2image import convert_from_path

# %%
def extract_text_from_pdf(pdf_path):
    text = ""
    try:
        # Try direct text extraction
        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                page_text = page.extract_text()
                if page_text:
                    text += page_text

        if text.strip():
            return text.strip()
    except Exception as e:
        print(f"Direct text extraction failed: {e}")

    # Fallback to OCR for image-based PDFs
    print("Falling back to OCR for image-based PDF.")
    try:
        images = convert_from_path(pdf_path)
        for image in images:
            page_text = pytesseract.image_to_string(image)
            text += page_text + "\n"
    except Exception as e:
        print(f"OCR failed: {e}")

    return text.strip()

# %%
pdf_path = "Jayanth_Resume.pdf"
resume_text = extract_text_from_pdf(pdf_path)

print("\nExtracted Text from PDF:")
print(resume_text)
# Out:
# Extracted Text from PDF:
# Jayanth Korada — Geeks for Geeks Profile
# Aspiring Software Engineer # jayanthkorada2003@gmail.com
# B.Tech in Computer Science and Engineering § GitHub Profile
# Eluru, Andhra Pradesh (cid:239) LinkedIn Profile
# +91-7702813298 (cid:140) HackerRank Profile
# Education
# •Bachelor of Technology in Computer Science and Engineering 2020-24
# SRM Institute of Science and Technology,Chennai,TamilNadu CGPA: 9.26
# Experience
# •Technology Summer Intern (April,2024 - December,2024) Chennai, TamilNadu
# Fiserv.
# – About Product: AggregateNow is a Financial Product in Fiserv that involves making digital payments accurately
# and maintains all financial institution data on one platform.
# – Role: Created and deployed advanced scripting solutions in JavaScript and XML, streamlining data processing
# workflows.Improved data processing efficiency by 25 Percent. Collaborated with cross-functional teams to resolve
# user issues.
# – Tech Stacks: SQL, JavaScript, XML, Puppeteer Framework
# Technical Skills and Interests
# Programming Languages: Python, C++, Java, JavaScript, HTML, CSS.
# Libraries and Frameworks: React.js, Node.js
# Development Tools: VS Code, Git, Docker, Kubernetes, Jenkins, Azure DevOps, Terraform
# Cloud and Databases: AWS, Relational Databases (MySQL)
# Relevant Coursework: Data Structures and Algorithms, Operating Systems, Object-Oriented Programming, Database
# Management Systems
# Areas of Interest: Software Development, Full Stack Development, Web Application Development.
# Personal Projects
# •Banking Management System View Project
# A Java-based Banking Management System with a graphical user interface (GUI) that simulates common ATM operations.
# – It allows users to perform various transactions such as deposits, withdrawals, balance inquiry, fast cash, PIN
# change, and view mini statements.
# – Technologies: Java,JDBC, MySQL,Swing.
# •An Adaption and Evaluation of Object Detection of small Objects using YOLOv8
# We have Proposed the Enhanced Object detection model for small objects in UAV captured imagery, addressing by the unique challenges.
# –The advancement of unmanned aerial vehicle (UAV) technology has impacted small object detection.
# We tried to rectify the problem with the help of the YOLO algorithm.
# –Technologies: In this project, we used several machine learning algorithms like YOLO and CNN and
# Python as a Programming Language.
# •My Personal Portfolio View Project
# A React.js based Application which showcases my skills, my personal contact details, educational details and Projects as well.
# – The Personal Portfolio Tells about my personal details, professional development, my skills, achievements and
# Projects which I built and it is deployed in Netlify platform.
# – Technologies: In this Project we have used React.js, Tailwind CSS and JSX. Key Libraries used are React Scroll
# and React Icons
# •Quiz Application View Project
# It is a JavaScript-based application where people can answer questions on various general topics.
# –Built a Quiz Web Application to provide an interactive and engaging way for users to test their
# knowledge on various topics.
# –Technologies: JavaScript, CSS, HTML.
# Certifications
# Learn DevOps: Docker, Kubernetes, Terraform, and Azure DevOps - Fiserv Certification URL
# Java Programming - A Complete Java course to Become Java Ace - Fiserv Certification URL
# Software Engineer Intern - HackerRank Certification URL
# Backend Web Development with NodeJS - GDG Ranchi Certification URL
# Programming With JavaScript - META Certification URL
# SQL - Fiserv Certification URL
# An Adaption and Evaluation for Object Detection of small objects using YOLOV8 - International Conference on
# Intelligent Computing and Emerging Communication Technologies (ICEC-2024) Certification URL
# Career Essentials in Generative AI by Microsoft and LinkedIn Certification URL

# %% [markdown]
# ## Set Google GenerativeAI Api Key

# %%
# %pip install google.generativeai python-dotenv
# Out:
# Collecting google.generativeai
#   Downloading google_generativeai-0.8.4-py3-none-any.whl.metadata (4.2 kB)
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting google-ai-generativelanguage==0.6.15 (from google.generativeai)
#   Downloading google_ai_generativelanguage-0.6.15-py3-none-any.whl.metadata (5.7 kB)
# Collecting google-api-core (from google.generativeai)
#   Downloading google_api_core-2.24.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting google-api-python-client (from google.generativeai)
#   Downloading google_api_python_client-2.161.0-py2.py3-none-any.whl.metadata (6.7 kB)
# Collecting google-auth>=2.15.0 (from google.generativeai)
#   Downloading google_auth-2.38.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting protobuf (from google.generativeai)
#   Downloading protobuf-5.29.3-cp38-abi3-macosx_10_9_universal2.whl.metadata (592 bytes)
# Collecting pydantic (from google.generativeai)
#   Downloading pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Collecting tqdm (from google.generativeai)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 502.9 kB/s eta 0:00:00a 0:00:01
# Collecting typing-extensions (from google.generativeai)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-ai-generativelanguage==0.6.15->google.generativeai)
#   Downloading proto_plus-1.26.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core->google.generativeai)
#   Downloading googleapis_common_protos-1.68.0-py2.py3-none-any.whl.metadata (5.1 kB)
# Collecting requests<3.0.0.dev0,>=2.18.0 (from google-api-core->google.generativeai)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=2.15.0->google.generativeai)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=2.15.0->google.generativeai)
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=2.15.0->google.generativeai)
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting httplib2<1.dev0,>=0.19.0 (from google-api-python-client->google.generativeai)
#   Downloading httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0 (from google-api-python-client->google.generativeai)
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client->google.generativeai)
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting annotated-types>=0.6.0 (from pydantic->google.generativeai)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic->google.generativeai)
#   Downloading pydantic_core-2.27.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting grpcio<2.0dev,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google.generativeai)
#   Downloading grpcio-1.70.0-cp312-cp312-macosx_10_14_universal2.whl.metadata (3.9 kB)
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google.generativeai)
#   Downloading grpcio_status-1.70.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google.generativeai)
#   Downloading pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google.generativeai)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google.generativeai) (3.4.1)
# Collecting idna<4,>=2.5 (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google.generativeai)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google.generativeai)
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google.generativeai)
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Downloading google_generativeai-0.8.4-py3-none-any.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 522.9 kB/s eta 0:00:00a 0:00:01
# Downloading google_ai_generativelanguage-0.6.15-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 2.1 MB/s eta 0:00:00a 0:00:01
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading google_api_core-2.24.1-py3-none-any.whl (160 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.1/160.1 kB 9.4 MB/s eta 0:00:00
# Downloading google_auth-2.38.0-py2.py3-none-any.whl (210 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.8/210.8 kB 8.6 MB/s eta 0:00:00
# Downloading protobuf-5.29.3-cp38-abi3-macosx_10_9_universal2.whl (417 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.8/417.8 kB 9.0 MB/s eta 0:00:00:00:01
# Downloading google_api_python_client-2.161.0-py2.py3-none-any.whl (12.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 4.5 MB/s eta 0:00:0000:0100:01
# Downloading pydantic-2.10.6-py3-none-any.whl (431 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.7/431.7 kB 5.1 MB/s eta 0:00:0000:0100:01
# Downloading pydantic_core-2.27.2-cp312-cp312-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 4.8 MB/s eta 0:00:00a 0:00:01
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 6.7 MB/s eta 0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Downloading googleapis_common_protos-1.68.0-py2.py3-none-any.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.0/165.0 kB 5.1 MB/s eta 0:00:00
# Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 5.0 MB/s eta 0:00:00
# Downloading proto_plus-1.26.0-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 3.8 MB/s eta 0:00:00
# Downloading pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 6.0 MB/s eta 0:00:00
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 4.9 MB/s eta 0:00:00
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.4/166.4 kB 5.5 MB/s eta 0:00:00
# Downloading grpcio-1.70.0-cp312-cp312-macosx_10_14_universal2.whl (11.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 6.1 MB/s eta 0:00:0000:0100:01
# Downloading grpcio_status-1.70.0-py3-none-any.whl (14 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 6.2 MB/s eta 0:00:00
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 7.2 MB/s eta 0:00:00
# Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 kB 7.2 MB/s eta 0:00:00
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.4/128.4 kB 7.1 MB/s eta 0:00:00
# Installing collected packages: urllib3, uritemplate, typing-extensions, tqdm, python-dotenv, pyparsing, pyasn1, protobuf, idna, grpcio, certifi, cachetools, annotated-types, rsa, requests, pydantic-core, pyasn1-modules, proto-plus, httplib2, googleapis-common-protos, pydantic, grpcio-status, google-auth, google-auth-httplib2, google-api-core, google-api-python-client, google-ai-generativelanguage, google.generativeai
# Successfully installed annotated-types-0.7.0 cachetools-5.5.2 certifi-2025.1.31 google-ai-generativelanguage-0.6.15 google-api-core-2.24.1 google-api-python-client-2.161.0 google-auth-2.38.0 google-auth-httplib2-0.2.0 google.generativeai-0.8.4 googleapis-common-protos-1.68.0 grpcio-1.70.0 grpcio-status-1.70.0 httplib2-0.22.0 idna-3.10 proto-plus-1.26.0 protobuf-5.29.3 pyasn1-0.6.1 pyasn1-modules-0.4.1 pydantic-2.10.6 pydantic-core-2.27.2 pyparsing-3.2.1 python-dotenv-1.0.1 requests-2.32.3 rsa-4.9 tqdm-4.67.1 typing-extensions-4.12.2 uritemplate-4.1.1 urllib3-2.3.0
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv

load_dotenv()

api_key = os.getenv("GOOGLE_API_KEY")
if api_key:
    print("API Key loaded successfully!")
else:
    print("Failed to load API Key. Check your .env file.")
# Out:
# API Key loaded successfully!

# %%
response = model.generate_content("What is the capital of India?")

# %%
print(response)
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "The capital of India is **New Delhi**.\n"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0026347806677222254
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 7,
#         "candidates_token_count": 10,
#         "total_token_count": 17
#       },
#       "model_version": "gemini-1.5-flash"
#     }),
# )

# %%
print(response.text)
# Out:
# The capital of India is **New Delhi**.

# %% [markdown]
# ## Resume Analysis

# %%
def analyze_resume(resume_text, job_description=None):
    if not resume_text:
        return {"error": "Resume text is required for analysis."}
    
    model = genai.GenerativeModel("gemini-1.5-flash")
    
    base_prompt = f"""
    You are an experienced HR with Technical Experience in the field of any one job role from Data Science, Data Analyst, DevOPS, Machine Learning Engineer, Prompt Engineer, AI Engineer, Full Stack Web Development, Big Data Engineering, Marketing Analyst, Human Resource Manager, Software Developer your task is to review the provided resume.
    Please share your professional evaluation on whether the candidate's profile aligns with the role.ALso mention Skills he already have and siggest some skills to imorve his resume , alos suggest some course he might take to improve the skills.Highlight the strengths and weaknesses.

    Resume:
    {resume_text}
    """

    if job_description:
        base_prompt += f"""
        Additionally, compare this resume to the following job description:
        
        Job Description:
        {job_description}
        
        Highlight the strengths and weaknesses of the applicant in relation to the specified job requirements.
        """

    response = model.generate_content(base_prompt)

    analysis = response.text.strip()
    return analysis

# %%
print(analyze_resume(resume_text))
# Out:
# ## Resume Evaluation for Jayanth Korada - Aspiring Software Engineer
#
# **Role:**  Assuming the target role is a Software Engineer (general), as the resume doesn't specify a particular niche.
#
# **Overall Impression:** Jayanth's resume demonstrates a solid foundation in software development with a good mix of theoretical knowledge and practical experience, particularly from his internship. However, it lacks focus and could benefit from significant restructuring and refinement to better highlight his strengths and target specific roles.
#
#
# **Strengths:**
#
# * **Strong Academic Record:** A CGPA of 9.26 indicates strong academic performance.
# * **Relevant Internship Experience:** The internship at Fiserv provides valuable real-world experience and quantifiable achievements (25% improvement in data processing efficiency).  This is a key strength.
# * **Diverse Skillset:** He possesses a broad range of skills, including programming languages (Python, Java, JavaScript, C++), frameworks (React.js, Node.js), cloud platforms (AWS, Azure), DevOps tools (Docker, Kubernetes, Jenkins, Terraform), and databases (MySQL).
# * **Multiple Personal Projects:**  The variety of personal projects showcases initiative and willingness to learn new technologies.  The YOLOv8 project is particularly impressive as it demonstrates an understanding of machine learning.
# * **Certifications:** Numerous certifications demonstrate a commitment to continuous learning.
#
#
# **Weaknesses:**
#
# * **Resume Structure and Formatting:** The resume is poorly formatted and lacks a clear, concise structure.  The use of symbols (cid) is unprofessional.  Information is scattered and not presented in a way that easily highlights key accomplishments.
# * **Lack of Focus:** The resume tries to showcase a broad range of skills, making it difficult to understand Jayanth's specific area of expertise.  A software engineer role often benefits from specialization.
# * **Weak Project Descriptions:** Project descriptions are too brief and lack quantifiable results wherever possible.  Instead of just listing technologies, explain the problem solved, the approach taken, and the outcome.
# * **Unclear Career Goals:**  The resume mentions "Aspiring Software Engineer," but doesn't clearly articulate long-term career aspirations or preferred role within software engineering.
# * **Overemphasis on Certifications:** While certifications are good, the resume lists too many, some of which might not be directly relevant to a Software Engineer role.  Prioritize the most impactful ones.
#
#
# **Skills:**
#
# **Existing Skills:**
#
# * **Programming Languages:** Python, Java, JavaScript, C++, HTML, CSS
# * **Frameworks/Libraries:** React.js, Node.js, Puppeteer
# * **Databases:** MySQL
# * **DevOps Tools:** Docker, Kubernetes, Jenkins, Azure DevOps, Terraform
# * **Cloud Platforms:** AWS, Azure
# * **Other:**  SQL, XML, Git, VS Code, JDBC, Swing
#
#
# **Skills to Improve:**
#
# * **Specific Software Engineering skills:** Depending on the target role, enhance skills in specific areas like testing (unit, integration, etc.), software design patterns, agile methodologies, and version control best practices.
# * **Data Structures and Algorithms:** Strengthen problem-solving abilities by practicing DSA extensively.
# * **System Design:** Learn the fundamentals of system design, especially if targeting senior-level positions.
# * **Communication Skills:**  Improve the ability to clearly articulate technical concepts both verbally and in writing.
#
#
# **Suggested Courses:**
#
# * **Advanced Data Structures and Algorithms:**  Coursera, Udacity, or similar platforms offer excellent courses.
# * **System Design Primer:**  Educative.io, Grokking the System Design Interview, or similar resources.
# * **Advanced React.js or Node.js:**  Depending on preferred specialization.
# * **Agile methodologies:**  Courses on Scrum, Kanban, etc.
# * **Software Testing and Quality Assurance:**  Courses on unit testing, integration testing, and other testing methodologies.
#
#
# **Recommendations:**
#
# 1. **Refocus and Reorganize:** Choose a specific area of software engineering to focus on (e.g., full-stack, backend, frontend, DevOps). Tailor the resume to highlight skills relevant to that area.
# 2. **Strengthen Project Descriptions:**  Use the STAR method (Situation, Task, Action, Result) to describe projects, quantifying accomplishments whenever possible.  Focus on the impact of your contributions.
# 3. **Improve Formatting and Clarity:** Use a professional resume template and ensure the content is concise, easy to read, and error-free.
# 4. **Add a Summary/Objective:**  Craft a compelling summary statement highlighting key skills and career goals.
# 5. **Tailor to Each Application:**  Customize the resume for each job application, highlighting the skills and experience most relevant to the specific role.
# 6. **Seek Feedback:**  Ask friends, family, or career counselors to review the resume for feedback.
#
#
# By addressing these weaknesses and focusing on his strengths, Jayanth can create a significantly more impactful resume that will better represent his skills and experience to potential employers.
